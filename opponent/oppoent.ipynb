# %%
from datasets import load_dataset
from gptqmodel import GPTQModel, QuantizeConfig

model_id = "/home/ubuntu/data/exp/proj2410/model/Llama2-7b"
quant_path = "/home/ubuntu/data/exp/proj2410/quant_model/Llama2-7B/gptq/w2g128"

calibration_dataset = load_dataset(
    "allenai/c4",
    data_files="en/c4-train.00001-of-01024.json.gz",
    split="train"
  ).select(range(1024))["text"]

quant_config = QuantizeConfig(bits=2, group_size=128)

model = GPTQModel.load(model_id, quant_config)

# increase `batch_size` to match gpu/vram specs to speed up quantization
model.quantize(calibration_dataset, batch_size=1)

model.save(quant_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from datasets import load_dataset
#       2 from gptqmodel import GPTQModel, QuantizeConfig
#       4 model_id = "/home/ubuntu/data/exp/proj2410/model/Llama2-7b"
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "4.4.1"
# ---> 17 from .arrow_dataset import Column, Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/datasets/arrow_dataset.py:108
#      95 from .filesystems import is_remote_filesystem
#      96 from .fingerprint import (
#      97     fingerprint_transform,
#      98     format_kwargs_for_fingerprint,
#    (...)    106     validate_fingerprint,
#     107 )
# --> 108 from .formatting import format_table, get_format_type_from_alias, get_formatter, query_table
#     109 from .formatting.formatting import LazyDict, _is_range_contiguous
#     110 from .info import DatasetInfo, DatasetInfosDict
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/datasets/formatting/__init__.py:95
#      92     _register_unavailable_formatter(_polars_error, "polars", aliases=["pl"])
#      94 if config.TORCH_AVAILABLE:
# ---> 95     from .torch_formatter import TorchFormatter
#      97     _register_formatter(TorchFormatter, "torch", aliases=["pt", "pytorch"])
#      98 else:
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/datasets/formatting/torch_formatter.py:38
#      36 # Import torch once at module level once
#      37 try:
# ---> 38     import torch
#      40     _torch_available = True
#      41 except ImportError:
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/torch/__init__.py:2161
#    2154 from torch._compile import _disable_dynamo  # usort: skip
#    2156 ################################################################################
#    2157 # Import interface functions defined in Python
#    2158 ################################################################################
#    2159
#    2160 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2161 from torch import _VF as _VF, functional as functional  # usort: skip
#    2162 from torch.functional import *  # usort: skip # noqa: F403
#    2164 ################################################################################
#    2165 # Remove unnecessary members
#    2166 ################################################################################
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/torch/functional.py:8
#       5 from typing import Any, Optional, TYPE_CHECKING, Union
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#      10 from torch._C import _add_docstr
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/torch/nn/__init__.py:8
#       1 # mypy: allow-untyped-defs
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)     16     utils as utils,
#      17 )
#      18 from torch.nn.parallel import DataParallel as DataParallel
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/torch/nn/modules/__init__.py:35
#       3 from .activation import (
#       4     CELU,
#       5     ELU,
#    (...)     32     Threshold,
#      33 )
#      34 from .adaptive import AdaptiveLogSoftmaxWithLoss
# ---> 35 from .batchnorm import (
#      36     BatchNorm1d,
#      37     BatchNorm2d,
#      38     BatchNorm3d,
#      39     LazyBatchNorm1d,
#      40     LazyBatchNorm2d,
#      41     LazyBatchNorm3d,
#      42     SyncBatchNorm,
#      43 )
#      44 from .channelshuffle import ChannelShuffle
#      45 from .container import (
#      46     Container,
#      47     ModuleDict,
#    (...)     51     Sequential,
#      52 )
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:9
#       6 from torch.nn import functional as F, init
#       7 from torch.nn.parameter import Parameter, UninitializedBuffer, UninitializedParameter
# ----> 9 from ._functions import SyncBatchNorm as sync_batch_norm
#      10 from .lazy import LazyModuleMixin
#      11 from .module import Module
#
# File ~/data/exp/proj2410/EfficientQAT/.venv/lib/python3.12/site-packages/torch/nn/modules/_functions.py:307
#     302                 accum_ratio.add_(paddded_ratio[c], alpha=-1)
#     304         return grad_input, None, None, None, None
# --> 307 class BackwardHookFunction(torch.autograd.Function):
#     308     @staticmethod
#     309     def forward(ctx, *args):
#     310         ctx.mark_non_differentiable(*[arg for arg in args if not arg.requires_grad])
#
# AttributeError: partially initialized module 'torch' has no attribute 'autograd' (most likely due to a circular import)
